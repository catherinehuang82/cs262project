# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv('logs/game0/game_log_0.csv', index_col=0)

df0
# Out:
#       active_id  passive_id  active_reliability  passive_reliability  \
# 0            86          29            0.870930             0.558799
# 1            86          30            0.870930             0.273452
# 2            30           7            0.273452             0.027274
# 3            70           3            0.132430             0.641834
# 4            24          91            0.378724             0.195943
# ...         ...         ...                 ...                  ...
# 4995         93          73            0.525495             0.854745
# 4996         53          43            0.047266             0.479471
# 4997         96          81            0.820893             0.633856
# 4998         73          86            0.854745             0.870930
# 4999         93          55            0.525495             0.523694
#
#       passive_opinion  accepted result  total_payout
# 0            0.550000      True   True             2
# 1            0.550000      True   True             4
# 2            0.450000      True  False             2
# 3            0.450000      True  False             0
# 4            0.450000      True  False            -2
# ...               ...       ...    ...           ...
# 4995         0.553533      True   True          1252
# 4996         0.497719     False      0          1252
# 4997         0.557751      True   True          1254
# 4998         0.498029     False      0          1254
# 4999         0.550938      True   True          1256
#
# [5000 rows x 8 columns]

# %%
plt.scatter(df0.index, df0['total_payout'], s=1)
plt.xlabel('Encounter Number')
plt.ylabel('Total Payout')
plt.title('Payout Over Time of One Run, 5000 Encounters')
# Out:
# Text(0.5, 1.0, 'Payout Over Time of One Run, 5000 Encounters')

# %%
plt.scatter(df0.index[:1000], df0['total_payout'][:1000], s=1)
plt.xlabel('Encounter Number')
plt.ylabel('Total Payout')
plt.title('Payout Over Time of One Run, 1000 Encounters')
# Out:
# Text(0.5, 1.0, 'Payout Over Time of One Run, 1000 Encounters')

# %%
plt.scatter(df0.index[:100], df0['total_payout'][:100], s=1)
plt.xlabel('Encounter Number')
plt.ylabel('Total Payout')
plt.title('Payout Over Time of One Run, 100 Encounters')
# Out:
# Text(0.5, 1.0, 'Payout Over Time of One Run, 100 Encounters')
